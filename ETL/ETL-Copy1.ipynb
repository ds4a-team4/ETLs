# %% [markdown]
# # Dataframe for Dynamic Pricing

# %% [markdown]
# ## Objectives
#
# This document intends to briefly describe one alternative for the ETL process for the Dynamic Pricing problem at Olist.
# As the end product, we would like to have a table with the proper structure for forecasting techniques.
# The datasets will be described along the way.

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd
import datetime

# %% [markdown]
# ### Dataframe with complete range
#
# Let's start by creating a dataframe with every data point we want to measure. It will contain hourly intervals, equally spaced between two dates.
# You can change the parameters in the cell below:

# %%
freq = 'D' # 'H' is for hourly data. You can use 'D' for days, 'W' for last day of week, 'Q' for quarter, etc.

start_date = '1/1/2017' # MM/DD/YYYY
end_date = '4/1/2020' # MM/DD/YYYY

# %%
df = pd.DataFrame(data=pd.date_range(start=start_date, end=end_date, freq=freq),
                  columns=['date'])

df.head(2)
# Out:
#         date
# 0 2017-01-01
# 1 2017-01-02

# %%
df.tail(2)
# Out:
#            date
# 1185 2020-03-31
# 1186 2020-04-01

# %% [markdown]
# ### Orders dataset
#
# Let's investigate our first dataset "orders.csv". It contains information for every sale that was executed in a given period of time.
# Our main idea is to aggregate sales data and merge it with our dates dataframe (df).

# %%
# READING ORDERS DATA AND TRANSFORMING COLUMNS
orders = pd.read_csv('data/orders.csv', dtype={'product_gtin':'str','origin_zip':'str',
                                               'destination_zip':'str'})

orders['purchase_timestamp'] = pd.to_datetime(orders['purchase_timestamp'])

# %%
orders.head()
# Out:
#    purchase_timestamp                             seller_id   product_gtin  \
# 0 2019-07-20 11:19:43  a97001a2-a7d2-4bd6-b0d5-1da2a2b8abd9  6952202281890
# 1 2019-11-11 20:43:23  a97001a2-a7d2-4bd6-b0d5-1da2a2b8abd9  6951003643197
# 2 2020-03-01 16:25:00  c58b83e5-52de-43fe-8399-a7bc312e2aa5  7898907175302
# 3 2020-02-04 12:04:10  a97001a2-a7d2-4bd6-b0d5-1da2a2b8abd9  6951003643197
# 4 2018-12-14 13:52:19  a97001a2-a7d2-4bd6-b0d5-1da2a2b8abd9  6951003643197
#
#         product_sku  channel_slug channel_store   price  freight_value  \
# 0  PRDWRHUYLLMFX2U0  mercadolivre  mercadolivre   82.99          20.86
# 1  PRDACYVT895VMO7H  mercadolivre  mercadolivre  119.90           0.00
# 2  PRDKTDU50G9FVV57         cnova            ex   39.90          14.24
# 3  PRDACYVT895VMO7H  mercadolivre  mercadolivre  130.95           0.00
# 4  PRDACYVT895VMO7H  mercadolivre  mercadolivre  128.99          21.51
#
#    price_freight_shift  commission_product_olist  commission_freight_olist  \
# 0                  0.0                      0.20                      0.20
# 1                  0.0                      0.20                      0.20
# 2                  0.0                      0.19                      0.19
# 3                  0.0                      0.20                      0.20
# 4                  0.0                      0.20                      0.20
#
#   origin_zip origin_state     origin_city destination_zip destination_state  \
# 0   01109010           SP       SAO PAULO        89265575                SC
# 1   01109010           SP       SAO PAULO        06040470                SP
# 2   20910970           RJ  RIO DE JANEIRO        22260210                RJ
# 3   01109010           SP       SAO PAULO        89062100                SC
# 4   01109010           SP       SAO PAULO        66055000                PA
#
#   destination_city
# 0   Jaraguá do Sul
# 1           Osasco
# 2   Rio de Janeiro
# 3         Blumenau
# 4            Belém

# %%
orders.product_gtin.nunique()
# Out:
# 647

# %% [markdown]
# ###### Selecting specific product
#
# In the orders dataset, we have sales information for 647 different products.
# For simplification purposes, let's choose one single product for analysis and manipulation of the dataset.
# To do so, choose a single gtin (str) in the cell below.
#
# - gtin = '7908243600137'
# - product_sku = 'PRD41RHHBF9NQR74'
# - canonical_sku = 'PRDIM5XOLWMUM0HU'

# %%
# FILTERING ORDERS DATASET BY CHOSEN GTIN

filter_orders = orders[['purchase_timestamp','product_gtin',
                        'price','freight_value',
                        'commission_product_olist','commission_freight_olist']].copy()

# ADD ARTIFICIAL COLUMN WITH THE NUMBER OF ORDERS -> WILL BE USED TO COUNT THE ORDERS BY HOUR
filter_orders['orders'] = 1


# GROUPS ORDERS BY CHOSEN FREQUENCY
filter_orders = filter_orders.groupby([pd.Grouper(key='purchase_timestamp', freq=freq),'product_gtin'])\
                  .agg({'price':'mean', 
                        'freight_value':'mean',
                        'commission_product_olist':'mean',
                        'commission_freight_olist':'mean',
                        'orders':'sum'}).reset_index()

# %%
filter_orders.head()
# Out:
#   purchase_timestamp   product_gtin  price  freight_value  \
# 0         2015-09-23  7899893323067  168.0          0.000
# 1         2015-10-13  7899893323067  168.0          0.000
# 2         2016-04-16  7898152189550  343.9         17.060
# 3         2016-06-10  7897889805825  129.9         28.540
# 4         2016-06-11  7897889805825  129.9         32.534
#
#    commission_product_olist  commission_freight_olist  orders
# 0                       0.2                       0.0       1
# 1                       0.2                       0.0       1
# 2                       0.2                       0.0       1
# 3                       0.2                       0.0       3
# 4                       0.2                       0.0       5

# %% [markdown]
# ##### merge date_range dataframe and orders
#
# Now that we have the number of sales of a given product by hour, along with its average price, average shipping values and average commissions (percentage), we can join with our date range dataframe.
#
# The 'NaN' rows are the ones that did not have any sales.

# %%
# MERGE DF and Filter orders

merged = pd.merge(df, filter_orders, how='left', left_on='date', right_on='purchase_timestamp')
merged.drop('purchase_timestamp', axis=1, inplace=True)

# %%
merged.head()
# Out:
#         date product_gtin  price  freight_value  commission_product_olist  \
# 0 2017-01-01          NaN    NaN            NaN                       NaN
# 1 2017-01-02          NaN    NaN            NaN                       NaN
# 2 2017-01-03          NaN    NaN            NaN                       NaN
# 3 2017-01-04          NaN    NaN            NaN                       NaN
# 4 2017-01-05          NaN    NaN            NaN                       NaN
#
#    commission_freight_olist  orders
# 0                       NaN     NaN
# 1                       NaN     NaN
# 2                       NaN     NaN
# 3                       NaN     NaN
# 4                       NaN     NaN

# %%
# Checking some rows with sales

merged[merged['orders'].notnull()].head()
# Out:
#          date   product_gtin   price  freight_value  commission_product_olist  \
# 5  2017-01-06  7891530258930  579.99          28.55                       0.2
# 7  2017-01-08  7898914878487   66.90          18.75                       0.2
# 8  2017-01-09  7898914878487   66.90          18.75                       0.2
# 10 2017-01-11  7891530258930  579.99          18.23                       0.2
# 11 2017-01-11  7897889805825  129.99          29.19                       0.2
#
#     commission_freight_olist  orders
# 5                        0.0     1.0
# 7                        0.0     1.0
# 8                        0.0     2.0
# 10                       0.0     1.0
# 11                       0.0     1.0

# %% [markdown]
# ### Product_info dataset
#
# Another available dataset is the "product_info.csv". We will use it to check when a product was created in our database to fine tune the starting point of our time series.

# %%
prod_info = pd.read_csv('data/product_info.csv', dtype={'gtin':'str'})

prod_info['created_at'] = pd.to_datetime(prod_info['created_at'])

# product creation date

# Get minimum creation date
# filter_prod = prod_info[prod_info['gtin']==gtin][['gtin','created_at']]
# filter_prod = filter_prod[filter_prod['created_at']==min(filter_prod['created_at'])]
# filter_prod = filter_prod.groupby(pd.Grouper(key='created_at',freq=freq)).min().reset_index()

# %%
filter_prod = prod_info[['created_at','gtin','name']]

# %%
filter_prod = filter_prod.groupby(['gtin','name']).min().reset_index()

# %%
filter_prod.head()
# Out:
#             gtin                                               name  \
# 0  1001001118649  Esqueleto 170 cm, Padrão, com Suporte e Base c...
# 1  1003001113372                       Autoclave Vertical 18 Litros
# 2  1003001209488  Mini Centrífuga Para 8 Microtubos Vol. 0,2 A 2...
# 3  1234567896618  Veda Fresta De Portão 6,4 Cm Altura Vedapratic...
# 4  1286508320126  Diabete composto 90 Cápsulas 500 Mg insulina n...
#
#            created_at
# 0 2019-06-03 14:50:41
# 1 2019-06-21 13:05:50
# 2 2019-12-02 12:38:41
# 3 2019-07-01 09:24:29
# 4 2019-01-24 13:10:00

# %%
filter_prod['created_at'][0].day
# Out:
# 3

# %%
def truncate_date(x):
    return datetime.date(x.year,x.month,x.day)

# %%
filter_prod['created_date'] = filter_prod['created_at'].map(truncate_date)

# %%
filter_prod.head()
# Out:
#             gtin                                               name  \
# 0  1001001118649  Esqueleto 170 cm, Padrão, com Suporte e Base c...
# 1  1003001113372                       Autoclave Vertical 18 Litros
# 2  1003001209488  Mini Centrífuga Para 8 Microtubos Vol. 0,2 A 2...
# 3  1234567896618  Veda Fresta De Portão 6,4 Cm Altura Vedapratic...
# 4  1286508320126  Diabete composto 90 Cápsulas 500 Mg insulina n...
#
#            created_at created_date
# 0 2019-06-03 14:50:41   2019-06-03
# 1 2019-06-21 13:05:50   2019-06-21
# 2 2019-12-02 12:38:41   2019-12-02
# 3 2019-07-01 09:24:29   2019-07-01
# 4 2019-01-24 13:10:00   2019-01-24

# %% [markdown]
# ##### Filter merged based on creation date

# %%
merged = pd.merge(merged, filter_prod, left_on='product_gtin', right_on='gtin', how='left')

# %%
# Exclude rows not necessary 
merged.head()
# Out:
#         date product_gtin  price  freight_value  commission_product_olist  \
# 0 2017-01-01          NaN    NaN            NaN                       NaN
# 1 2017-01-02          NaN    NaN            NaN                       NaN
# 2 2017-01-03          NaN    NaN            NaN                       NaN
# 3 2017-01-04          NaN    NaN            NaN                       NaN
# 22868                     0.160                     0.160     1.0
# 22869                     0.200                     0.200     1.0
#
#                 gtin                                               name  \
# 5      7891530258930               Relógio Technos Ts Carbon Os10er/1r.
# 7      7898914878487  Caixa de Pesca Com 6 Bandejas Articuladas CX-6...
# 8      7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 9      7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 10     7898914878487  Caixa de Pesca Com 6 Bandejas Articuladas CX-6...
# 11     7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 12     7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 14     7891530258930               Relógio Technos Ts Carbon Os10er/1r.
# 15     7897889805825  Mesinha Didática de Atividades Infantil 2 Cade...
# 16     7891530258930               Relógio Technos Ts Carbon Os10er/1r.
# 17     7898943954053  Adipômetro/Plicômetro Clínico Innovare - Cesco...
# 18     7898914878487  Caixa de Pesca Com 6 Bandejas Articuladas CX-6...
# 19     7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 20     7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 21     7898943954053  Adipômetro/Plicômetro Clínico Innovare - Cesco...
# 22     7899621100984  Coq10 200Mg - 60 Capsulas - Atlhetica Clinical...
# 23     7899621100984  Coq10 200mg  60 Capsulas  Atlhetica Clinical S...
# 24     7899621100984  Coq10 200mg - 60 Capsulas - Atlhetica Clinical...
# 26     7897889805825  Mesinha Didática de Atividades Infantil 2 Cade...
# 27     7898943954053  Adipômetro/Plicômetro Clínico Innovare - Cesco...
# 28     7897889805825  Mesinha Didática de Atividades Infantil 2 Cade...
# 29     7897889805825  Mesinha Didática de Atividades Infantil 2 Cade...
# 30     7898943954053  Adipômetro/Plicômetro Clínico Innovare - Cesco...
# 31     7897889805825  Mesinha Didática de Atividades Infantil 2 Cade...
# 32     7898943954053  Adipômetro/Plicômetro Clínico Innovare - Cesco...
# 33     7898914878487  Caixa de Pesca Com 6 Bandejas Articuladas CX-6...
# 34     7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 35     7898914878487  Caixa de pesca 6 bandejas com divisórias model...
# 37     7897889805825  Mesinha Didática de Atividades Infantil 2 Cade...
# 38     7909389107160          Prato Giratório 80 cm em Madeira Laminado
# ...              ...                                                ...
# 22840  7899121843114  Ventilador Oscilante de Parede 60cm Venti-Delt...
# 22841  7899121843114  Ventilador de Parede Venti-Delta 73-6425 Premi...
# 22842  7899121843114  Ventilador de Parede Venti-Delta 73-6425 Premi...
# 22843  7899459304660    Escova progressiva Maria Escandalosa  2x1000 ml
# 22844  7899459304660  INATIVO Escova progressiva Maria Escandalosa  ...
# 22845  7899459304660     Kit Escova Progressiva Maria Escandalosa  2x1l
# 22846  7899495703106         Maleta Kit Maquiagem Profissional Completa
# 22847  7899495703106  Maleta Kit Maquiagem Profissional Completa Rub...
# 22848  7899886027804             Cabo de Força Novo Padrão 10A 3 metros
# 22849  7908157707601                 Quadro Decorativo Cozinha Temperos
# 22841 2017-06-29 18:27:00   2017-06-29
# 22842 2016-10-17 16:54:11   2016-10-17
# 22843 2017-11-23 13:27:26   2017-11-23
# 22844 2017-11-23 13:27:27   2017-11-23
# 22845 2018-10-27 19:50:36   2018-10-27
# 22846 2019-03-27 10:06:42   2019-03-27
# 22847 2019-03-27 10:06:42   2019-03-27
# 22848 2019-05-31 10:53:14   2019-05-31
# 22849 2018-09-03 08:05:12   2018-09-03
# 22850 2019-03-15 15:00:28   2019-03-15
# 22851 2017-02-17 10:58:31   2017-02-17
# 22852 2017-02-10 11:49:11   2017-02-10
# 22853 2016-12-21 15:31:51   2016-12-21
# 22854 2017-05-05 09:36:24   2017-05-05
# 22855 2017-06-30 11:12:55   2017-06-30
# 22856 2016-12-08 18:04:20   2016-12-08
# 22857 2017-03-14 17:50:46   2017-03-14
# 22858 2018-11-26 15:40:25   2018-11-26
# 22859 2020-02-03 12:23:17   2020-02-03
# 22860 2018-03-12 09:33:12   2018-03-12
# 22861 2018-10-27 11:56:53   2018-10-27
# 22862 2016-09-15 19:46:13   2016-09-15
# 22863 2019-03-14 13:00:18   2019-03-14
# 22864 2018-10-27 18:42:07   2018-10-27
# 22865 2017-06-29 18:27:00   2017-06-29
# 22866 2016-10-17 16:54:11   2016-10-17
# 22867 2019-03-27 10:06:42   2019-03-27
# 22868 2019-03-27 10:06:42   2019-03-27
# 22869 2019-03-15 15:00:28   2019-03-15
#
# [22805 rows x 11 columns]

# %%
merged = merged[merged['date']>=merged['created_date']].copy()

# %%
merged.head()
# Out:
#          date   product_gtin   price  freight_value  commission_product_olist  \
# 5  2017-01-06  7891530258930  579.99          28.55                       0.2
# 7  2017-01-08  7898914878487   66.90          18.75                       0.2
# 8  2017-01-08  7898914878487   66.90          18.75                       0.2
# 10 2017-01-09  7898914878487   66.90          18.75                       0.2
# 11 2017-01-09  7898914878487   66.90          18.75                       0.2
#
#     commission_freight_olist  orders           gtin  \
# 5                        0.0     1.0  7891530258930
# 7                        0.0     1.0  7898914878487
# 8                        0.0     1.0  7898914878487
# 10                       0.0     2.0  7898914878487
# 11                       0.0     2.0  7898914878487
#
#                                                  name          created_at  \
# 5                Relógio Technos Ts Carbon Os10er/1r. 2016-07-24 13:30:02
# 7   Caixa de Pesca Com 6 Bandejas Articuladas CX-6... 2016-10-02 22:16:36
# 8   Caixa de pesca 6 bandejas com divisórias model... 2016-10-17 15:23:04
# 10  Caixa de Pesca Com 6 Bandejas Articuladas CX-6... 2016-10-02 22:16:36
# 11  Caixa de pesca 6 bandejas com divisórias model... 2016-10-17 15:23:04
#
#    created_date
# 5    2016-07-24
# 7    2016-10-02
# 8    2016-10-17
# 10   2016-10-02
# 11   2016-10-17

# %%
# filter merged dataframe to keep only the dates after the creation date.
merged = merged[merged['date']>=creation_date].copy()

# fill gtin backfill information
merged['product_gtin'] = merged['product_gtin'].fillna(method='bfill')
merged['product_gtin'] = merged['product_gtin'].fillna(method='ffill')
# fill NaN orders with 0 - no orders on that timestamp
merged['orders'] = merged['orders'].fillna(value=0)

# %%
merged.head()

# %%
merged.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Competition
#
# Now, let's get our competitor's prices by the same frequency.

# %%
# Read data and format it
competition = pd.read_csv('data/competition.csv', dtype={'gtin':'str'})

competition['updated_at'] = pd.to_datetime(competition['updated_at'])

# FILTER GTIN
competition = competition[competition['gtin'] == gtin]

# %%
competition.head()

# %%
# filter competition on extremely low and high prices
std = competition['value'].std()
mean = competition['value'].mean()

competition = competition[(competition['value']>= mean-3*std) & (competition['value']<= mean+3*std)]

# %%
# Group by freq and get minimum value
competition = competition.groupby([pd.Grouper(key='updated_at', freq=freq),'gtin']).min()[['value']].reset_index()

# %%
competition.head()

# %% [markdown]
# ##### merge competition prices with merged dataframe

# %%
#merged['day'] = merged['date'].apply(lambda x: x.date())

# %%
merged = pd.merge(merged, competition,
         left_on=['date','product_gtin'], right_on=['updated_at', 'gtin'],
         how='left')

merged.rename(columns={'value':'competition_price'}, inplace=True)

merged = merged[['date', 'product_gtin',  'competition_price', 'price', 'freight_value',
       'commission_product_olist', 'commission_freight_olist', 'orders']].copy()

# %%
merged.head()

# %% [markdown]
# We will forward fill the competition price.

# %%
merged['competition_price'].fillna(method='ffill', inplace=True)

# %%
merged.head()

# %%
merged.tail()

# %% [markdown]
# ### Product type and group
#
# Let's gather some information about the type of the analyzed product.
#
# This particular gtin belongs to the product_type "Kit para cabelo" (Hair Care Kit).
# The product belongs to the broader group "beleza_saude" (beauty_health)

# %%
product_type = pd.read_csv('data/product_type.csv', dtype={'value':str})

product_type.head()

product_type[product_type['value']==gtin]

merged.columns

merged = pd.merge(left=merged, right=product_type,
         left_on='product_gtin', right_on='value')[['date', 'product_gtin', 'competition_price',
                                                    'price', 'freight_value', 'commission_product_olist', 
                                                    'commission_freight_olist', 'orders','product_type', 
                                                    'product_type_group']]

# %%
merged.head()

# %% [markdown]
# ### Olist history of prices
# ### TODO
#
# For this particular case, we will only read historical data for the selected gtin. This will be changed once olist can share data on other products.
# Due to internal issues, the price history could not be gathered.

# %%
# history = pd.read_csv('data/product_history.csv', dtype={'gtin':str})
# history['updated_at'] = pd.to_datetime(history['updated_at'])

# %% [markdown]
# ### SOME CHARTS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

# %%
merged.columns

# %%
trace0 = go.Scatter(x=merged.date,
                   y=merged.orders, mode='lines')

trace1 = go.Scatter(x=merged.date,
                    y=merged.competition_price, mode='markers')

trace2 = go.Scatter(x=merged.date,
                    y=merged.price,
                    mode='markers')

trace3 = go.Scatter(x=merged.date,
                    y=merged.freight_value,
                    mode='lines')


iplot([trace0, trace1, trace2, trace3])

# %%
plt.figure(figsize=(12,8))

plt.style.use('fivethirtyeight')

sns.lineplot(x='date', y='orders', data=merged)
sns.scatterplot(x='date', y='competition_price', data=merged, label='competitor')
sns.scatterplot(x='date', y='price', data=merged, label='olist')

plt.legend()

plt.tight_layout()
plt.show()

# %%
sum(merged['orders'])
